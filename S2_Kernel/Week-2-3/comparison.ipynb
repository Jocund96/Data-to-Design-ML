# %%
import pandas as pd

knn   = pd.read_csv('./results/KNN_results.csv')
svr   = pd.read_csv('./results/SVR_results.csv')
nusvr = pd.read_csv('./results/nuSVR_results.csv')

results = pd.concat([knn, svr, nusvr]).reset_index(drop=True)
print(results)
# Out:
#    model  Test Samples       MAE      RMSE         R        R2  Samples
# 0    kNN         201.0  6.670972  8.948846  0.862297  0.743556      NaN
# 1    SVR           NaN  4.243227  6.063228  0.939295  0.882276    201.0
# 2  NuSVR         201.0  3.893600  6.091960  0.938700  0.881157      NaN
