# %% [markdown]
# # Data cleaning

# %%
from sklearn.impute import SimpleImputer, KNNImputer
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r"../Datasets/uci_concrete_data.xlsx", sheet_name="Sheet1")
df.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1048.000000
# mean                                  281.491308
# std                                   104.162471
# min                                   102.000000
# 25%                                   194.680000
# 50%                                   274.000000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1050.000000
# mean                                           73.794694
# std                                            86.110710
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.725000
# max                                           359.400000
#
#        Fly Ash (component 3)(kg in a m^3 mixture)  \
# count                                 1042.000000
# mean                                    54.148015
# std                                     63.786094
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                    118.270000
# max                                    200.100000
#
#        Water  (component 4)(kg in a m^3 mixture)  \
# count                                1051.000000
# mean                                  181.448016
# std                                    21.322325
# min                                   121.750000
# 25%                                   164.900000
# 50%                                   185.000000
# 75%                                   192.000000
# max                                   247.000000
#
#        Superplasticizer (component 5)(kg in a m^3 mixture)  \
# count                                        1080.000000
# mean                                            6.231984
# std                                             5.944312
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             6.350000
# 75%                                            10.160000
# max                                            32.200000
#
#        Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# count                                        1080.000000
# mean                                          973.076670
# std                                            77.447901
# min                                           801.000000
# 25%                                           932.000000
# 50%                                           968.000000
# 75%                                          1029.400000
# max                                          1145.000000
#
#        Fine Aggregate (component 7)(kg in a m^3 mixture)    Age (day)  \
# count                                        1080.000000  1080.000000
# mean                                          773.390569    45.392082
# std                                            79.864558    62.353966
# min                                           594.000000     1.000000
# 25%                                           732.050000    14.000000
# 50%                                           779.320000    28.000000
# 75%                                           822.650000    56.000000
# max                                           992.600000   365.000000
#
#        Concrete compressive strength(MPa, megapascals)
# count                                       1080.000000
# mean                                          35.907088
# std                                           16.535634
# min                                            2.331808
# 25%                                           23.880001
# 50%                                           34.346247
# 75%                                           46.089490
# max                                           82.599225

# %%
df.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                32
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    30
# Fly Ash (component 3)(kg in a m^3 mixture)               38
# Water  (component 4)(kg in a m^3 mixture)                29
# Superplasticizer (component 5)(kg in a m^3 mixture)       0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)      0
# Fine Aggregate (component 7)(kg in a m^3 mixture)         0
# Age (day)                                                 0
# Concrete compressive strength(MPa, megapascals)           0
# dtype: int64

# %% [markdown]
# ### SimpleImputer

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(df)
df_sim_imp = pd.DataFrame(imp.transform(df), columns=df.columns)
#print(df_sim_imp)
#df_sim_imp.isnull().sum()

# %% [markdown]
# ### Nearest neighbors imputation

# %%
imp_near = KNNImputer(n_neighbors=5, weights='distance')
df_near = pd.DataFrame(imp_near.fit_transform(df), columns=df.columns)
#df_near.isnull().sum()
#df_near

# %% [markdown]
# ### Dropping the rows

# %%
df_drop = df.dropna()

#df_drop.isnull().sum()

df_drop.describe()
#df.isnull().sum()
#df.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.165631
# std                                   104.507142
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895485
# std                                            86.279104
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# max                                           359.400000
#
#        Fly Ash (component 3)(kg in a m^3 mixture)  \
# count                                 1030.000000
# mean                                    54.187136
# std                                     63.996469
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                    118.270000
# max                                    200.100000
#
#        Water  (component 4)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  181.566359
# std                                    21.355567
# min                                   121.750000
# 25%                                   164.900000
# 50%                                   185.000000
# 75%                                   192.000000
# max                                   247.000000
#
#        Superplasticizer (component 5)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                            6.203112
# std                                             5.973492
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             6.350000
# 75%                                            10.160000
# max                                            32.200000
#
#        Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                          972.918592
# std                                            77.753818
# min                                           801.000000
# 25%                                           932.000000
# 50%                                           968.000000
# 75%                                          1029.400000
# max                                          1145.000000
#
#        Fine Aggregate (component 7)(kg in a m^3 mixture)    Age (day)  \
# count                                        1030.000000  1030.000000
# mean                                          773.578883    45.662136
# std                                            80.175427    63.169912
# min                                           594.000000     1.000000
# 25%                                           730.950000     7.000000
# 50%                                           779.510000    28.000000
# 75%                                           824.000000    56.000000
# max                                           992.600000   365.000000
#
#        Concrete compressive strength(MPa, megapascals)
# count                                       1030.000000
# mean                                          35.817836
# std                                           16.705679
# min                                            2.331808
# 25%                                           23.707115
# 50%                                           34.442774
# 75%                                           46.136287
# max                                           82.599225

# %% [markdown]
# ### Drop duplicates

# %%
df_drop.duplicated().sum()
df_drop_dup = df_drop.drop_duplicates()
df_drop_dup.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Correlation with respect to compressive strength

# %%
df_drop_dup.corr() #Pearson correlation
# we look to the highest positive and the lowest negative ratio wwith respect to compressive strength
# Out:
#                                                     Cement (component 1)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                            1.000000
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                  -0.303301
# Fly Ash (component 3)(kg in a m^3 mixture)                                          -0.385618
# Water  (component 4)(kg in a m^3 mixture)                                           -0.056583
# Superplasticizer (component 5)(kg in a m^3 mixt...                                   0.061296
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                  -0.086212
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                   -0.245379
# Age (day)                                                                            0.086349
# Concrete compressive strength(MPa, megapascals)                                      0.488283
#
#                                                     Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                                   -0.303301
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                           1.000000
# Fly Ash (component 3)(kg in a m^3 mixture)                                                  -0.312342
# Water  (component 4)(kg in a m^3 mixture)                                                    0.130295
# Superplasticizer (component 5)(kg in a m^3 mixt...                                           0.019902
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                          -0.277558
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                           -0.289676
# Age (day)                                                                                   -0.042759
# Concrete compressive strength(MPa, megapascals)                                              0.103370
#
#                                                     Fly Ash (component 3)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                            -0.385618
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                   -0.312342
# Fly Ash (component 3)(kg in a m^3 mixture)                                            1.000000
# Water  (component 4)(kg in a m^3 mixture)                                            -0.283372
# Superplasticizer (component 5)(kg in a m^3 mixt...                                    0.414055
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                   -0.026485
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                     0.090229
# Age (day)                                                                            -0.158940
# Concrete compressive strength(MPa, megapascals)                                      -0.080648
#
#                                                     Water  (component 4)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                           -0.056583
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                   0.130295
# Fly Ash (component 3)(kg in a m^3 mixture)                                          -0.283372
# Water  (component 4)(kg in a m^3 mixture)                                            1.000000
# Superplasticizer (component 5)(kg in a m^3 mixt...                                  -0.646875
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                  -0.212495
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                   -0.444888
# Age (day)                                                                            0.279269
# Concrete compressive strength(MPa, megapascals)                                     -0.269606
#
#                                                     Superplasticizer (component 5)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                                    0.061296
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                           0.019902
# Fly Ash (component 3)(kg in a m^3 mixture)                                                   0.414055
# Water  (component 4)(kg in a m^3 mixture)                                                   -0.646875
# Superplasticizer (component 5)(kg in a m^3 mixt...                                           1.000000
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                          -0.242031
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                            0.207794
# Age (day)                                                                                   -0.194094
# Concrete compressive strength(MPa, megapascals)                                              0.344225
#
#                                                     Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                                   -0.086212
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                          -0.277558
# Fly Ash (component 3)(kg in a m^3 mixture)                                                  -0.026485
# Water  (component 4)(kg in a m^3 mixture)                                                   -0.212495
# Superplasticizer (component 5)(kg in a m^3 mixt...                                          -0.242031
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                           1.000000
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                           -0.162212
# Age (day)                                                                                   -0.005263
# Concrete compressive strength(MPa, megapascals)                                             -0.144710
#
#                                                     Fine Aggregate (component 7)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                                   -0.245379
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                          -0.289676
# Fly Ash (component 3)(kg in a m^3 mixture)                                                   0.090229
# Water  (component 4)(kg in a m^3 mixture)                                                   -0.444888
# Superplasticizer (component 5)(kg in a m^3 mixt...                                           0.207794
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                          -0.162212
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                            1.000000
# Age (day)                                                                                   -0.156572
# Concrete compressive strength(MPa, megapascals)                                             -0.186457
#
#                                                     Age (day)  \
# Cement (component 1)(kg in a m^3 mixture)            0.086349
# Blast Furnace Slag (component 2)(kg in a m^3 mi...  -0.042759
# Fly Ash (component 3)(kg in a m^3 mixture)          -0.158940
# Water  (component 4)(kg in a m^3 mixture)            0.279269
# Superplasticizer (component 5)(kg in a m^3 mixt...  -0.194094
# Coarse Aggregate  (component 6)(kg in a m^3 mix...  -0.005263
# Fine Aggregate (component 7)(kg in a m^3 mixture)   -0.156572
# Age (day)                                            1.000000
# Concrete compressive strength(MPa, megapascals)      0.337371
#
#                                                     Concrete compressive strength(MPa, megapascals)
# Cement (component 1)(kg in a m^3 mixture)                                                   0.488283
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                          0.103370
# Fly Ash (component 3)(kg in a m^3 mixture)                                                 -0.080648
# Water  (component 4)(kg in a m^3 mixture)                                                  -0.269606
# Superplasticizer (component 5)(kg in a m^3 mixt...                                          0.344225
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                         -0.144710
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                          -0.186457
# Age (day)                                                                                   0.337371
# Concrete compressive strength(MPa, megapascals)                                             1.000000

# %% [markdown]
# ### Visualization

# %%
df_drop_dup.boxplot(rot=90, figsize=(12,8), fontsize=6)
plt.show()

# %% [markdown]
# ### Differentiate input and output data

# %%
X = df.iloc[:, 0:8]
Y = df.iloc[:, 8]
# X = df_drop_dup.iloc[:, 0:8]
# Y = df_drop_dup.iloc[:, 8]

# %% [markdown]
# ### Common seed

# %%
from sklearn.model_selection import train_test_split, KFold

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
kf = KFold(n_splits=4, random_state=42, shuffle=True)

# %% [markdown]
# # Boosting

# %% [markdown]
# ## Raw data without cleaning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import HistGradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ### Histogram Gradient Boosting

# %%
# hist = HistGradientBoostingRegressor(random_state=42)
# gridSe = GridSearchCV(estimator=hist, param_grid={'max_iter': (50, 100, 200, 300, 500, 1000), 'max_depth': (3,4,5,10,20,50,100,None)}, cv=kf)

# %% [markdown]
# #### Fit a model

# %%
# gridSe_fit = gridSe.fit(X_train, Y_train)
# gridSe_fit_best_params = gridSe_fit.best_params_
# print(gridSe_fit_best_params)

# %% [markdown]
# #### Prediction

# %%
# hist_Y_pred = gridSe_fit.predict(X_test)

# %% [markdown]
# #### Calculation of Metrics

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score

# %%
# hist_mae = mean_absolute_error(Y_test, hist_Y_pred)
# hist_r2 = r2_score(Y_test, hist_Y_pred)
# hist_rmse = root_mean_squared_error(Y_test,hist_Y_pred)
# hist_residual = np.subtract(Y_test, hist_Y_pred)

# %%
# metrics_dict = {"MAE":[hist_mae], "RMSE":[hist_rmse], "R":[hist_r2]}
# hist_metrics = pd.DataFrame(metrics_dict)
# hist_metrics

# %%
# plt.scatter(hist_Y_pred, hist_residual, c="m")
# plt.axhline(0)
# plt.figure()
# plt.show()

# %% [markdown]
# ### Comparison beteween XGBRegressor and HistGradientBoostingRegressor

# %%
models = {'XGBRegressor': XGBRegressor(random_state=42), 
          'HistGradientBoostingRegressor': HistGradientBoostingRegressor(random_state=42),
          'AdaBoostRegressor':AdaBoostRegressor(random_state=42)}
params = {'XGBRegressor':{'n_estimators': (50, 100, 200, 300, 500, 1000), 'max_depth': (3,4,5,10,20,50,100,None)},
          'HistGradientBoostingRegressor':{'max_iter': (50, 100, 200, 300, 500, 1000), 'max_depth': (3,4,5,10,20,50,100,None)},
          'AdaBoostRegressor':{'n_estimators': (50, 100, 200, 300, 500, 1000)}}


# XGBoost evaluates the Gain for each possible split and selects the best one.
# HistGradientBoostingRegressor splits the data to bins (255 by default)

# %%
grid_loop = {}
grid_loop_best_params = {}
Y_pred = {}
mae = {}
rmse = {}
r2 = {}
residual = {}

for name, model in models.items():
    if name == 'AdaBoostRegressor':
        continue
    grid_loop[name] = GridSearchCV(estimator=model, param_grid=params[name], cv=kf)
    grid_loop[name].fit(X_train, Y_train)
    grid_loop_best_params[name] = grid_loop[name].best_params_
    Y_pred[name] = grid_loop[name].predict(X_test)
    mae[name] = mean_absolute_error(Y_test, Y_pred[name])
    rmse[name] = root_mean_squared_error(Y_test,Y_pred[name])
    r2[name] = r2_score(Y_test, Y_pred[name])
    residual[name] = np.subtract(Y_test, Y_pred[name])

# %%
metrics_dict = {"MAE":mae, "RMSE":rmse, "R":r2, "BestParams": grid_loop_best_params}
metrics = pd.DataFrame(metrics_dict)
params_df=metrics['BestParams'].apply(pd.Series)
metrics = metrics.drop(columns=['BestParams'])
final_metrics = pd.concat([metrics, params_df], axis=1)

final_metrics
# Out:
#                                     MAE      RMSE         R  max_depth  \
# XGBRegressor                   3.091311  4.585227  0.921693        3.0
# HistGradientBoostingRegressor  3.323602  4.828930  0.913148        3.0
#
#                                n_estimators  max_iter
# XGBRegressor                          500.0       NaN
# HistGradientBoostingRegressor           NaN    1000.0

# %%
fig, axes = plt.subplots(1, 2)
axes[0].scatter(Y_pred['XGBRegressor'], residual['XGBRegressor'], c="m")
axes[1].scatter(Y_pred['HistGradientBoostingRegressor'], residual['HistGradientBoostingRegressor'], c="m")
axes[0].axhline(0)
axes[1].axhline(0)
plt.show()

# %% [markdown]
# ## Boosting models after data cleaning

# %%
X_c = df_drop_dup.iloc[:, 0:8]
Y_c = df_drop_dup.iloc[:, 8]

# %%
X_train_c, X_test_c, Y_train_c, Y_test_c = train_test_split(X_c, Y_c, test_size=0.2, random_state=42)
kf_c = KFold(n_splits=4, random_state=42, shuffle=True)

# %%
grid_loop_c = {}
grid_loop_best_params_c = {}
Y_pred_c = {}
mae_c = {}
rmse_c = {}
r2_c = {}
residual_c = {}
for name, model in models.items():
    grid_loop_c[name] = GridSearchCV(estimator=model, param_grid=params[name], cv=kf_c)
    grid_loop_c[name].fit(X_train_c, Y_train_c)
    grid_loop_best_params_c[name] = grid_loop_c[name].best_params_
    Y_pred_c[name] = grid_loop_c[name].predict(X_test_c)
    mae_c[name] = mean_absolute_error(Y_test_c, Y_pred_c[name])
    rmse_c[name] = root_mean_squared_error(Y_test_c,Y_pred_c[name])
    r2_c[name] = r2_score(Y_test_c, Y_pred_c[name])
    residual_c[name] = np.subtract(Y_test_c, Y_pred_c[name])

# %%
metrics_dict_c = {"MAE_CD":mae_c, "RMSE_CD":rmse_c, "R_CD":r2_c, "BestParams_CD": grid_loop_best_params_c}
metrics_c = pd.DataFrame(metrics_dict_c)
params_df_c=metrics_c['BestParams_CD'].apply(pd.Series)
metrics_c = metrics_c.drop(columns=['BestParams_CD'])
final_metrics_c = pd.concat([metrics_c, params_df_c], axis=1)

# %%
fig, axes = plt.subplots(1, 2)
axes[0].scatter(Y_pred_c['XGBRegressor'], residual_c['XGBRegressor'], c="m")
axes[1].scatter(Y_pred_c['HistGradientBoostingRegressor'], residual_c['HistGradientBoostingRegressor'], c="m")
axes[0].axhline(0)
axes[1].axhline(0)
plt.show()

# %%
final_metrics
# Out:
#                                     MAE      RMSE         R  max_depth  \
# XGBRegressor                   3.091311  4.585227  0.921693        3.0
# HistGradientBoostingRegressor  3.323602  4.828930  0.913148        3.0
#
#                                n_estimators  max_iter
# XGBRegressor                          500.0       NaN
# HistGradientBoostingRegressor           NaN    1000.0

# %%
final_metrics_c
# Out:
#                                  MAE_CD   RMSE_CD      R_CD  max_depth  \
# XGBRegressor                   3.061706  4.731200  0.928319        3.0
# HistGradientBoostingRegressor  2.846749  4.611775  0.931893        5.0
# AdaBoostRegressor              6.394625  7.685703  0.810842        NaN
#
#                                n_estimators  max_iter
# XGBRegressor                          500.0       NaN
# HistGradientBoostingRegressor           NaN    1000.0
# AdaBoostRegressor                     500.0       NaN
